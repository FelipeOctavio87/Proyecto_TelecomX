# %% [markdown]
# # Telecom X Etapa 1: Churn de Clientes
# ## Indice:
# ### 1 Descripción del Proyecto
# ### 2 Extracción y Transformación de datos
# ### 3 Análisis Exploratorio (EDA) y Visualización de Datos
# ### 4 Puntos Clave: Interpretación y Representación de Datos
# ### 5 Análisis de Correlación

# %% [markdown]
# # 1 Descripción del Proyecto

# %% [markdown]
# # 2 Extracción y Transformación de datos

# %%
import requests
import pandas as pd

url = "https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json"
response = requests.get(url)
data = response.json()

df = pd.DataFrame(data)

df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
import pandas as pd
df_plano = pd.json_normalize(data)
df_plano
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
df_plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
# Cambiando la columna "Charges total" desde tipo object a tipo float64

df_plano['account.Charges.Total'] = pd.to_numeric(df_plano['account.Charges.Total'], errors='coerce')
df_plano['account.Charges.Total']

df_plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
df_plano.isnull().sum()
df_plano['account.Charges.Total'] = df_plano['account.Charges.Total'].fillna(0)

# %%
df_plano.loc[:, 'Charges.Daily'] = round(df_plano['account.Charges.Monthly'] / 30, 2)
print(df_plano[['account.Charges.Monthly', 'Charges.Daily']]) # Printeamos para chequear nuestra nueva columna creada
# Out:
#       account.Charges.Monthly  Charges.Daily
# 0                       65.60           2.19
# 1                       59.90           2.00
# 2                       73.90           2.46
# 3                       98.00           3.27
# 4                       83.90           2.80
# ...                       ...            ...
# 7262                    55.15           1.84
# 7263                    85.10           2.84
# 7264                    50.30           1.68
# 7265                    67.85           2.26
# 7266                    59.00           1.97
#
# [7267 rows x 2 columns]

# %%
for col in df_plano.columns:
    print(f'Columna: {col}')
    print(df_plano[col].unique())
    print('-' * 50)
# Out:
# Columna: customerID
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# --------------------------------------------------
# Columna: Churn
# ['No' 'Yes' '']
# --------------------------------------------------
# Columna: customer.gender
# ['Female' 'Male']
# --------------------------------------------------
# Columna: customer.SeniorCitizen
# [0 1]
# --------------------------------------------------
# Columna: customer.Partner
# ['Yes' 'No']
# --------------------------------------------------
# Columna: customer.Dependents
# ['Yes' 'No']
# --------------------------------------------------
# Columna: customer.tenure
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# --------------------------------------------------
# Columna: phone.PhoneService
# ['Yes' 'No']
# ...

# %%
for col in df_plano.columns:
  print(f"valores únicos en la columna'{col}': {df_plano[col].nunique()}")
  if df_plano[col].nunique() < 50: # Imprima los valores solamente si no hay muchos
    print(df_plano[col].unique())
    print('-' * 50)  # Línea divisoria para mejor visualización
# Out:
# valores únicos en la columna'customerID': 7267
# valores únicos en la columna'Churn': 3
# ['No' 'Yes' '']
# --------------------------------------------------
# valores únicos en la columna'customer.gender': 2
# ['Female' 'Male']
# --------------------------------------------------
# valores únicos en la columna'customer.SeniorCitizen': 2
# [0 1]
# --------------------------------------------------
# valores únicos en la columna'customer.Partner': 2
# ['Yes' 'No']
# --------------------------------------------------
# valores únicos en la columna'customer.Dependents': 2
# ['Yes' 'No']
# --------------------------------------------------
# valores únicos en la columna'customer.tenure': 73
# valores únicos en la columna'phone.PhoneService': 2
# ['Yes' 'No']
# --------------------------------------------------
# valores únicos en la columna'phone.MultipleLines': 3
# ['No' 'Yes' 'No phone service']
# --------------------------------------------------
# ...

# %%
df_plano.duplicated().sum() # Comprobando si existen duplicados
# Out:
# np.int64(0)

# %%
df_plano.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# Charges.Daily                0
# dtype: int64

# %%
df_plano.apply(lambda x: x.astype(str).str.strip()=="").sum()
# Out:
# customerID                     0
# Churn                        224
# customer.gender                0
# customer.SeniorCitizen         0
# customer.Partner               0
# customer.Dependents            0
# customer.tenure                0
# phone.PhoneService             0
# phone.MultipleLines            0
# internet.InternetService       0
# internet.OnlineSecurity        0
# internet.OnlineBackup          0
# internet.DeviceProtection      0
# internet.TechSupport           0
# internet.StreamingTV           0
# internet.StreamingMovies       0
# account.Contract               0
# account.PaperlessBilling       0
# account.PaymentMethod          0
# account.Charges.Monthly        0
# account.Charges.Total          0
# Charges.Daily                  0
# dtype: int64

# %% [markdown]
# No podemos inferir lo que querían decir los 224 registros vacíos de 'Churn' ya que completar estos arbitrariamente podría perjudicar el análisis, por lo que los almacenaremos en otra variable, posterior a eso podemos eliminarlos del dataframe con el que haremos el análisis.

# %%
df_plano = df_plano[df_plano['Churn'].str.strip()!=""] # Removiendo filas que tengan valores vacíos en la columna Churn

# %%
df_plano.apply(lambda x: x.astype(str).str.strip() == '').sum() # Comprobando que no hay valores vacíos de strings en las columnas
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# Charges.Daily                0
# dtype: int64

# %%
len(df_plano) # Comprobando número de filas
# Out:
# 7043

# %%
df_plano.head(3)
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
#
#   internet.InternetService  ... internet.DeviceProtection  \
# 0                      DSL  ...                        No
# 1                      DSL  ...                        No
# 2              Fiber optic  ...                       Yes
#
#   internet.TechSupport internet.StreamingTV internet.StreamingMovies  \
# ...

# %%
print(df_plano['Churn'].value_counts(normalize=True))
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df_plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7043 non-null   object
#  1   Churn                      7043 non-null   object
#  2   customer.gender            7043 non-null   object
#  3   customer.SeniorCitizen     7043 non-null   int64
#  4   customer.Partner           7043 non-null   object
#  5   customer.Dependents        7043 non-null   object
#  6   customer.tenure            7043 non-null   int64
#  7   phone.PhoneService         7043 non-null   object
#  8   phone.MultipleLines        7043 non-null   object
#  9   internet.InternetService   7043 non-null   object
#  10  internet.OnlineSecurity    7043 non-null   object
#  11  internet.OnlineBackup      7043 non-null   object
#  12  internet.DeviceProtection  7043 non-null   object
# ...

# %%
columnas = df_plano.columns
columnas
# Out:
# Index(['customerID', 'Churn', 'customer.gender', 'customer.SeniorCitizen',
#        'customer.Partner', 'customer.Dependents', 'customer.tenure',
#        'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService',
#        'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract',
#        'account.PaperlessBilling', 'account.PaymentMethod',
#        'account.Charges.Monthly', 'account.Charges.Total', 'Charges.Daily'],
#       dtype='object')

# %%
nuevas_columnas = [
    columnas
    .str.replace('customer.', '')
    .str.replace('phone.', '')
    .str.replace('internet.', '')
    .str.replace('account.', '').tolist()
]

nuevas_columnas
# Out:
# [['customerID',
#   'Churn',
#   'gender',
#   'SeniorCitizen',
#   'Partner',
#   'Dependents',
#   'tenure',
#   'PhoneService',
#   'MultipleLines',
#   'InternetService',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'Contract',
#   'PaperlessBilling',
#   'PaymentMethod',
#   'Charges.Monthly',
#   'Charges.Total',
#   'Charges.Daily']]

# %%
df_plano.columns = nuevas_columnas[0]

# %%
df_plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
# Estableciendo Variables Categóricas

columnas_categoricas = ['Churn', 'gender', 'SeniorCitizen', 'Partner',
       'Dependents', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']
for columna in columnas_categoricas:
    print(f'Valores unicos en columna {columna}:\n{df_plano[columna].unique()}\n')
# Out:
# Valores unicos en columna Churn:
# ['No' 'Yes']
#
# Valores unicos en columna gender:
# ['Female' 'Male']
#
# Valores unicos en columna SeniorCitizen:
# [0 1]
#
# Valores unicos en columna Partner:
# ['Yes' 'No']
#
# Valores unicos en columna Dependents:
# ['Yes' 'No']
#
# Valores unicos en columna PhoneService:
# ['Yes' 'No']
#
# Valores unicos en columna MultipleLines:
# ['No' 'Yes' 'No phone service']
#
# Valores unicos en columna InternetService:
# ['DSL' 'Fiber optic' 'No']
#
# Valores unicos en columna OnlineSecurity:
# ['No' 'Yes' 'No internet service']
#
# Valores unicos en columna OnlineBackup:
# ['Yes' 'No' 'No internet service']
#
# Valores unicos en columna DeviceProtection:
# ['No' 'Yes' 'No internet service']
#
# Valores unicos en columna TechSupport:
# ['Yes' 'No' 'No internet service']
#
# Valores unicos en columna StreamingTV:
# ['Yes' 'No' 'No internet service']
#
# Valores unicos en columna StreamingMovies:
# ['No' 'Yes' 'No internet service']
#
# ...

# %% [markdown]
# La variable SeniorCitizen tiene valores 0 y 1. Esto nos podría perjudicar la inconsistencia del analisis con el resto de las variables.
#
# Por lo que la modificaremos para mantener el formato con las otras columnas.

# %%
# Estableciendo 0 y 1 por 'Yes' y 'No'

df_plano.loc[:, 'SeniorCitizen'] = df_plano['SeniorCitizen'].apply(lambda row: 'Yes' if row == 1 else 'No')
# Out:
# /tmp/ipython-input-1576208225.py:3: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['No' 'No' 'No' ... 'No' 'No' 'No']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.

# %% [markdown]
# las columnas [OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies] == 'No internet service' se cambiará por 'No'
#
# MultipleLines donde el valor es No phone service también se cambiará por 'No'

# %%
df_plano.loc[:, 'MultipleLines'] = df_plano['MultipleLines'].apply(lambda row: row.replace('No phone service', 'No'))

# %%
columna_servicios = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                    'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
for columna in columna_servicios:
    df_plano.loc[:, columna] = df_plano[columna].replace('No internet service', 'No')

# %%
columnas_categoricas = ['Churn', 'gender', 'SeniorCitizen', 'Partner',
       'Dependents', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']
for columna in columnas_categoricas:
    print(f'Valores unicos en columna {columna}:\n{df_plano[columna].unique()}\n')
# Out:
# Valores unicos en columna Churn:
# ['No' 'Yes']
#
# Valores unicos en columna gender:
# ['Female' 'Male']
#
# Valores unicos en columna SeniorCitizen:
# ['No' 'Yes']
#
# Valores unicos en columna Partner:
# ['Yes' 'No']
#
# Valores unicos en columna Dependents:
# ['Yes' 'No']
#
# Valores unicos en columna PhoneService:
# ['Yes' 'No']
#
# Valores unicos en columna MultipleLines:
# ['No' 'Yes']
#
# Valores unicos en columna InternetService:
# ['DSL' 'Fiber optic' 'No']
#
# Valores unicos en columna OnlineSecurity:
# ['No' 'Yes']
#
# Valores unicos en columna OnlineBackup:
# ['Yes' 'No']
#
# Valores unicos en columna DeviceProtection:
# ['No' 'Yes']
#
# Valores unicos en columna TechSupport:
# ['Yes' 'No']
#
# Valores unicos en columna StreamingTV:
# ['Yes' 'No']
#
# Valores unicos en columna StreamingMovies:
# ['No' 'Yes']
#
# Valores unicos en columna Contract:
# ['One year' 'Month-to-month' 'Two year']
#
# Valores unicos en columna PaperlessBilling:
# ['Yes' 'No']
#
# ...

# %%
df_plano.head(5)
# Out:
#    customerID Churn  gender SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female            No     Yes        Yes       9
# 1  0003-MKNFE    No    Male            No      No         No       9
# 2  0004-TLHLJ   Yes    Male            No      No         No       4
# 3  0011-IGKFF   Yes    Male           Yes     Yes         No      13
# 4  0013-EXCHZ   Yes  Female           Yes     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df_plano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %%
df_plano.describe()
# Out:
#             tenure  Charges.Monthly  Charges.Total  Charges.Daily
# count  7043.000000      7043.000000    7043.000000    7043.000000
# mean     32.371149        64.761692    2279.734304       2.158675
# std      24.559481        30.090047    2266.794470       1.003088
# min       0.000000        18.250000       0.000000       0.610000
# 25%       9.000000        35.500000     398.550000       1.180000
# 50%      29.000000        70.350000    1394.550000       2.340000
# 75%      55.000000        89.850000    3786.600000       2.990000
# max      72.000000       118.750000    8684.800000       3.960000

# %% [markdown]
# Para entender con mayor claridad los elementos que inciden en la deserción de clientes en la compañía Telecom X, se proponen las siguientes interrogantes que guiarán el análisis:
#
# Ciclo de permanencia y Rentabilidad del cliente
#
# ¿Hay vínculo entre el tiempo de permanencia del cliente y su decisión de retirarse?
#
# ¿Existe relación entre el consumo mensual del cliente y su inclinación a abandonar la empresa?
#
# ¿Se observa conexión entre el gasto acumulado durante todo el ciclo de vida del cliente en la compañía y la probabilidad de desvinculación?
#
# Servicios
#
# ¿Alguno de los servicios (PhoneService o InternetService) ejerce mayor impacto en la pérdida de clientes?
#
# ¿Hay asociación entre la cantidad de servicios contratados y la renuncia del cliente?
#
# ¿Qué tipo de contrato adquirido por el cliente muestra mayor propensión a la cancelación?
#
# ¿Alguna forma de pago influye en la decisión de abandono del cliente?
#
# Información del cliente
#
# ¿Algún sexo presenta una mayor predisposición a dejar la empresa?
#
# ¿La edad (particularmente ser un adulto mayor) incide en la probabilidad de que un cliente se retire?
#
# ¿Se relaciona la situación familiar del cliente (pareja, dependientes) con la posibilidad de abandono?

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
px.histogram(df_plano, x="gender")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from pathlib import Path

# Creando un objeto Path
# Esto crea un directorio si es que no existe.

figures_path = Path('figures')
figures_path.mkdir(parents=True, exist_ok=True)

print(f"Figures will be saved to: {figures_path}")
# Out:
# Figures will be saved to: figures

# %%
# Visualizar la proporción de registros en relación a la evasión (Churn)
churns = df_plano.groupby('Churn')['Churn'].value_counts()
churns = pd.DataFrame(churns)
fig, ax = plt.subplots(figsize=(6,5))
ax = plt.pie(data=churns,
             x=churns['count'],
             labels=["Churn = 'No'", "Churn = 'Yes'"],
             autopct='%1.1f%%',
             colors=['#FF0000', '#00FF00'] # Updated custom colors (Red for No, Green for Yes)
             )

plt.title('Proporción Churn (Evasión)', fontsize=16)

fig.savefig(figures_path/'proporción_churn_pie.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')
plt.show()

# %% [markdown]
# # 3 Análisis Exploratorio y Visualización de Datos

# %% [markdown]
# ## Ciclo de permanencia y Rentabilidad del cliente

# %% [markdown]
# ### 1. ¿Hay vínculo entre el tiempo de permanencia del cliente y su decisión de retirarse?

# %%
def boxplot_churn(df: pd.DataFrame,
                  ycol: str,
                  ylabel: str=None,
                  title_translate: str=None):

    if ylabel is None:
        ylabel = ycol
    if title_translate is None:
        title_translate = ycol

    fig, ax = plt.subplots(figsize=(8, 5))

    ax = sns.boxplot(data=df_plano, x='Churn', y=ycol, hue='Churn', palette=churn_colors)
    plt.title(f'Distribución de {title_translate} según\nEvasión (Churn) de clientes', fontsize=18, pad=20)
    plt.xlabel('Churn', fontsize=15)
    plt.ylabel(ylabel, fontsize=15)
    plt.xticks(fontsize=13)
    plt.grid(True)

    fig.savefig(figures_path/f'boxplot_Churn_{ycol}.png',
                transparent=False,
                dpi=300,
                bbox_inches='tight')
    plt.show()
    return fig

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# Define churn colors
churn_colors = {'No': '#FF0000', 'Yes': '#00FF00'}

boxplot_tenure = boxplot_churn(df_plano,
                               ycol='tenure', # Changed 'Tenure' to 'tenure' to match DataFrame
                               title_translate='Antigüedad (Tenure)')

# %%
def hist_churn(df,
                     xcol,
                     xlabel: str=None):

    if xlabel is None:
        xlabel = xcol

    fig, axes = plt.subplots(2,1, figsize=(8,6))

    sns.histplot(data=df[df['Churn'] == 'No'], x=xcol, bins=30, color=churn_colors['No'], kde=True, ax=axes[0])
    axes[0].set_title("Churn = 'No'", fontsize=15, fontweight='bold', loc='left', color='teal')
    axes[0].set_xlabel(xlabel, fontsize=13)
    axes[0].set_ylabel('Frecuencia', fontsize=13)

    sns.histplot(data=df[df['Churn'] == 'Yes'], x=xcol, bins=30,  color=churn_colors['Yes'], kde=True, ax=axes[1])
    axes[1].set_title("Churn = 'Yes'", fontsize=15, fontweight='bold', loc='left', color='indianred')
    axes[1].set_xlabel(xlabel, fontsize=13)
    axes[1].set_ylabel('Frecuencia', fontsize=13)

    # Ajustar limite eje Y
    ymax1 = axes[0].get_ylim()[1]
    ymax2 = axes[1].get_ylim()[1]

    ymax = max(ymax1, ymax2)

    axes[0].set_ylim(0, ymax)
    axes[1].set_ylim(0, ymax)

    # Configuraciones figura
    sns.despine()
    plt.suptitle(f'Distribución de {xlabel} según Evasión (Churn)', fontsize=18, y=1.01)
    plt.subplots_adjust(hspace=2)
    plt.tight_layout()

    fig.savefig(f'{figures_path}/hist_Churn_{xcol}.png',
                    transparent=False,
                    dpi=300,
                    bbox_inches='tight')

    plt.show()
    return fig

# %%
hist_tenure = hist_churn(df_plano, 'tenure', 'Tenure (meses)')

# %% [markdown]
# Observaciones: Distribución de Antigüedad (Tenure) en relación con la Pérdida de clientes (Churn).
#
# Boxplot Churn == 'No'
#
# Rasgos principales:
#
# La caja se extiende desde los 16 hasta los 61 meses, aproximadamente.
#
# La mediana se sitúa en torno a los 38 meses.
#
# El bigote inferior alcanza el valor 0 y el superior llega hasta 72.
#
# Interpretación:
#
# La distribución es más equilibrada y amplia, lo que refleja una mayor variabilidad entre los clientes que continúan en la compañía.
#
# La mediana de 38 meses indica que la mitad de los clientes más fieles han permanecido más de 3 años.
#
# Boxplot Churn == 'Yes'
#
# Rasgos principales:
#
# La mediana se ubica en 10 meses.
#
# Los límites de la caja van desde los 2 hasta los 29 meses aproximadamente.
#
# El bigote inferior se sitúa en 1 mes y el superior en torno a 69, con algunos valores atípicos (outliers) por encima de este rango.
#
# Interpretación:
#
# La caja resulta más compacta en comparación con el gráfico de Churn == 'No', lo que muestra una distribución más concentrada.
#
# Mediana = 10: el 50% de los clientes que se desvinculan de la empresa lo hacen con 10 meses o menos de permanencia.
#
# El tercer cuartil (Q3) se localiza en 29 meses, lo que implica que el 75% de los clientes que cancelan lo hacen antes de llegar a 30 meses de relación con la compañía.
#
# Conclusiones:
#
# Se observa una marcada propensión al abandono entre los clientes recientes, ya que la mayoría de las bajas ocurren antes del primer año.
#
# Sería relevante examinar con mayor detalle a los clientes con una permanencia entre 16 y 30 meses, para comprender qué elementos inciden en su retención o en su salida en esa etapa intermedia.
#
# Asimismo, conviene profundizar en el perfil de quienes tienen menos de 15 meses de antigüedad, con el fin de detectar oportunidades de mejora en la experiencia inicial del cliente.

# %% [markdown]
# ### 2. ¿Existe relación entre el consumo mensual del cliente y su inclinación a abandonar la empresa?

# %%
hist_chargesmonthly = hist_churn(df_plano, 'Charges.Monthly', 'Gasto Mensual')

# %%
boxplot_charges_montly = boxplot_churn(df_plano,
                               ycol='Charges.Monthly',
                               title_translate='Gasto Mensual (ChargesMonthly)')

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax = sns.histplot(data=df_plano[df_plano['Churn'] == 'Yes'], x='Charges.Monthly', bins=30, color=churn_colors['Yes'], kde=True)
ax.set_title("Churn = 'Yes'", fontsize=15, fontweight='bold', loc='left', color='chocolate')
ax.set_xlabel('Gasto Mensual', fontsize=13)
ax.set_ylabel('Frecuencia', fontsize=13)

plt.suptitle('Distribución de Gasto Mensual para clientes que abandonan', fontsize=18)
plt.tight_layout()

fig.savefig(figures_path/'hist_ChurnYes_ChargesMonthly.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')

plt.show()

# %% [markdown]
# Observaciones: Distribución del Gasto Mensual (Charges.Monthly) en relación con la Deserción de clientes (Churn).
#
# Boxplot Churn == 'No'
#
# Rasgos principales:
#
# Mediana cercana a 65 USD.
#
# El gasto mensual de los usuarios que optan por permanecer en la compañía asciende hasta cerca de 88 USD (Q3).
#
# No se detectan valores atípicos.
#
# Interpretación:
#
# Mediana ≈ 65: El 50% de los clientes que continúan en la empresa desembolsan hasta 65 USD mensuales.
#
# Rango intercuartílico (IQR): La dispersión de los clientes que permanecen es más amplia en comparación con quienes se desvinculan, con un rango aproximado de 53 USD (88 - 25). Esto sugiere que los clientes que permanecen muestran conformidad con el costo de los servicios contratados cada mes.
#
# Boxplot Churn == 'Yes'
#
# Rasgos principales:
#
# El 50% (Q1 a Q3) de los clientes que abandonan registra un gasto mensual entre 56 y 95 USD (límites de la caja).
#
# Mediana cercana a 79 USD.
#
# No se observan valores atípicos.
#
# Interpretación:
#
# La caja correspondiente a Churn == 'Yes' resulta más estrecha que la de Churn == 'No', similar al análisis anterior, lo que refleja una distribución más concentrada entre quienes se retiran. Esto puede indicar que el gasto mensual es un factor relevante en la decisión de abandono.
#
# Mediana ≈ 79: el 50% de los clientes que dejan la compañía tiene un gasto mensual de hasta 79 USD.
#
# Entre el primer cuartil (Q1 = 56) y la mediana (Q2 = 79), la dispersión es mayor, lo que sugiere que la percepción de descontento con el precio en este rango puede estar influida por distintos motivos.
#
# Tercer cuartil (Q3 = 95): el 75% de los clientes que cancelan sus servicios gastan hasta unos 90-95 USD mensuales, reforzando la importancia de este rango en el abandono.
#
# Conclusiones:
#
# La mediana de gasto mensual de los clientes que desertan (≈79 USD) coincide con el consumo de cerca del 68% de los clientes que permanecen. Esto indica que aquellos con un gasto superior a 79 USD constituyen un grupo con alto riesgo de abandono.
#
# La variabilidad en la inconformidad con los precios entre 56 y 79 USD al mes amerita un análisis más detallado del tipo y la cantidad de servicios contratados, así como del costo asociado, para comprender por qué deciden desertar.
#
# La concentración de clientes con gastos entre 79 y 96 USD es crítica: una diferencia de apenas 11 USD agrupa a una cuarta parte de quienes se dan de baja. Esto sugiere que la empresa podría ajustar su política de precios o implementar promociones que fomenten la permanencia, al menos hasta los 18 meses de relación, considerando que en el análisis previo se observó que los clientes con más de 16 meses tienden a mantenerse.

# %% [markdown]
# ### 3. ¿Se observa conexión entre el gasto acumulado durante todo el ciclo de vida del cliente en la compañía y la probabilidad de abandono?

# %%
boxplot_charges_total = boxplot_churn(df_plano,
                               ycol='Charges.Total',
                               title_translate='Gasto Total (Charges.Total)')

# %%
hist_chargestotal = hist_churn(df_plano, 'Charges.Total', 'Gasto Total')

# %% [markdown]
# Observaciones: Distribución del Gasto Acumulado (ChargesTotal) en relación con la Deserción de clientes (Churn).
#
# Boxplot Churn == 'No'
#
# Rasgos principales:
#
# Los límites de la caja van desde el primer cuartil ~700 hasta el tercer cuartil ~4200.
#
# Mediana cercana a 1800.
#
# No se registran valores atípicos.
#
# Interpretación:
#
# El 50% de los clientes que permanecen en la compañía presenta un gasto total entre 700 y 4200 USD, lo que refleja una relación más estable y consolidada con la organización.
#
# Boxplot Churn == 'Yes'
#
# Rasgos principales:
#
# Los límites de la caja se ubican entre el cuartil 1 ~50 y el cuartil 3 ~2200.
#
# Mediana alrededor de 800.
#
# Se observan múltiples registros con valores atípicos.
#
# Interpretación:
#
# Existe una fuerte concentración de clientes que se retiran con un gasto acumulado entre ~50 y ~800 USD. Considerando que el gasto promedio mensual es de 64 USD, esto coincide con la conclusión previa de que gran parte de las bajas ocurren antes de cumplir un año de permanencia.
#
# Valores atípicos: Se identifica un número considerable de clientes con un gasto total elevado que igualmente han abandonado la empresa. Es razonable suponer que corresponden a clientes con mayor antigüedad, ya que sus gastos superan los 5500 USD. Estos no aparecieron en los análisis anteriores, lo que sugiere que, si bien la tendencia general es el abandono en etapas iniciales, existe un segmento de usuarios que se desvincula tras una relación prolongada. Este grupo merece un estudio diferenciado para comprender los factores que motivaron su salida y definir posibles estrategias de fidelización.
#
# Conclusiones:
#
# El análisis confirma lo observado previamente: el abandono se concentra mayoritariamente en las primeras etapas de la relación con la empresa.
#
# Sin embargo, también se detecta un subconjunto de clientes con larga permanencia y gastos acumulados significativos que igualmente decidieron darse de baja. Este hallazgo señala la necesidad de estudiar este grupo en particular para identificar las causas de su decisión y diseñar medidas específicas de retención.

# %% [markdown]
# Conclusiones: Permanencia y Rentabilidad del cliente
#
# De las tres interrogantes asociadas a esta sección, se desprende lo siguiente:
#
# La duración de la relación (Tenure) y el gasto acumulado (Charges.Total) presentan una fuerte asociación con la deserción de clientes, por lo que ambas variables se configuran como elementos clave a considerar en un modelo de predicción de abandono.
#
# Se detectó un segmento de clientes de alto valor que igualmente optan por retirarse, lo que contrasta con la tendencia general de abandono temprano. Este grupo debería ser analizado en mayor detalle —ya sea mediante entrevistas posteriores a la baja o a través de análisis multivariados— con el fin de identificar patrones recurrentes o factores detonantes, y así establecer mecanismos de alerta anticipada.
#
# Existe una marcada concentración de bajas cuando el gasto mensual supera los 79 USD, dentro de un rango de aproximadamente 11 USD. Esto sugiere la posibilidad de una sensibilidad al precio en el tramo medio-alto, potencialmente influenciada por la competencia. Este hallazgo refuerza la importancia de examinar la relación entre MonthlyCharges, el portafolio de servicios contratados y el churn, con el propósito de optimizar tanto las estrategias de fijación de precios como las acciones de fidelización.

# %% [markdown]
# ## Servicios

# %% [markdown]
# ### 4. ¿Alguno de los servicios (PhoneService o InternetService) ejerce mayor impacto en la pérdida de clientes?

# %%
# Creamos un dataframe para hacer el análisis
df_servicios = df_plano.copy()

# %%
# limpiamos la base de columnas que no se utlizarán
df_servicios.drop(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'], axis=1, inplace=True)
df_servicios.head()
# Out:
#   Churn PhoneService MultipleLines InternetService OnlineSecurity  \
# 0    No          Yes            No             DSL             No
# 1    No          Yes           Yes             DSL             No
# 2   Yes          Yes            No     Fiber optic             No
# 3   Yes          Yes            No     Fiber optic             No
# 4   Yes          Yes            No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0          Yes               No         Yes         Yes              No
# 1           No               No          No          No             Yes
# 2           No              Yes          No          No              No
# 3          Yes              Yes          No         Yes             Yes
# 4           No               No         Yes         Yes              No
#
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# ...

# %%
# Otro DataFrame para el Servicio de Teléfono (PhoneService)
df_phone = df_servicios.groupby('Churn')['PhoneService'].value_counts().to_frame()
df_phone.reset_index(inplace=True)

# %%
df_phone
# Out:
#   Churn PhoneService  count
# 0    No          Yes   4662
# 1    No           No    512
# 2   Yes          Yes   1699
# 3   Yes           No    170

# %%
from typing import Callable, List, Dict, Tuple

def bar_churn(df: pd.DataFrame,
              xcol: str,
              ycol: str='count',
              hue_col: str='Churn',
              figsize: Tuple=(6,4),
              title_translate: str=None,
              xlabel: str=None,
              ylabel: str='Cantidad de clientes'):

    fig, ax = plt.subplots(figsize=figsize)

    if title_translate is None:
        title_translate = xcol

    ax = sns.barplot(data=df, x=xcol, y=ycol, hue=hue_col, palette=churn_colors)
    ax.set_title(f'Evasión (Churn) según {title_translate}', fontsize=18, pad=20)
    if xlabel is None:
        ax.set_xlabel('')
    else:
        ax.set_xlabel(xcol, fontsize=15)

    ax.set_ylabel(ylabel, fontsize=15)
    ax.tick_params(axis='y', labelsize=10)
    ax.tick_params(axis='x', labelsize=12)
    for bar in ax.patches:
        height = bar.get_height()
        if height == 0:
            continue
        else:
            ax.text(bar.get_x() + bar.get_width() / 2,
                    height + 30,
                    f'{height:.0f}',
                    ha='center')

    sns.despine()
    #plt.tight_layout()

    fig.savefig(figures_path/f'bar_Churn_{xcol}.png',
                transparent=False,
                dpi=300,
                bbox_inches='tight')

    plt.show()
    return fig

# %%
bar_phoneservice = bar_churn(df_phone,
                             xcol='PhoneService',
                             xlabel='PhoneService',
                             title_translate='\nServicio Telefónico (PhoneService)')

# %%
df_phone = df_phone.pivot(index='PhoneService', columns='Churn', values='count')
df_phone.columns = ['No Churn', 'Churn']
df_phone.reset_index(inplace=True)

# %%
valores_no_churn = df_phone['No Churn']
valores_churn = df_phone['Churn']
labels = ['No tiene Phone Service', 'Tiene Phone Service']

# Creando figura
fig, axes = plt.subplots(1, 2, figsize=(8, 5))

# Porsión (explode)
explode = (0.05, 0.05)

# Torta (pie) para clientes que NO se fueron (Churn = 'No')
axes[0].pie(valores_no_churn,
            labels=labels,
            autopct='%1.1f%%',
            startangle=90,
            explode=explode,
            colors=sns.color_palette(['powderblue', churn_colors['Yes']])
           )
axes[0].set_title("Churn = 'No'", fontsize=15, fontweight='bold', color='teal')

# Torta (pie) para clientes que SÍ se fueron (Churn = 'Yes')
axes[1].pie(valores_churn,
            labels=labels,
            autopct='%1.1f%%',
            startangle=90,
            explode=explode,
            colors=sns.color_palette(['#ffe1d3', churn_colors['No']])
           )
axes[1].set_title("Churn = 'Yes'", fontsize=15, fontweight='bold', color='chocolate')

# Título
plt.suptitle('Phone Service\n Evasión Comparada (Churn)', fontsize=18)

plt.tight_layout()
plt.subplots_adjust(hspace=0.8)

fig.savefig(figures_path/'torta_Churn_PhoneService.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')

plt.show()

# %% [markdown]
# Observaciones: Servicio Telefónico
# La participación relativa de clientes con servicio telefónico que optan por permanecer o darse de baja de la empresa difiere únicamente en un 0,8%, lo que sugiere que esta variable, de manera aislada, carece de relevancia explicativa.

# %%
df_internet_service = df_servicios.groupby('InternetService')['Churn'].value_counts().to_frame()
df_internet_service
# Out:
#                        count
# InternetService Churn
# DSL             No      1962
#                 Yes      459
# Fiber optic     No      1799
#                 Yes     1297
# No              No      1413
#                 Yes      113

# %%
bar_internetservice = bar_churn(df_internet_service,
                                  xcol='InternetService',
                                  figsize=(8,5),
                                  title_translate='\nServicio de Internet (InternetService)'
                                )

# %% [markdown]
# Tasa de Deserción según Tipo de InternetService

# %%
df_internet_service.reset_index(inplace=True)
df_internet_service
# Out:
#   InternetService Churn  count
# 0             DSL    No   1962
# 1             DSL   Yes    459
# 2     Fiber optic    No   1799
# 3     Fiber optic   Yes   1297
# 4              No    No   1413
# 5              No   Yes    113

# %%
def pivot_y_tasa_abandono(df: pd.DataFrame,
                          index_col: str):
    df = df.pivot(index=index_col, columns='Churn', values='count')
    df.columns = ['No Churn', 'Churn']
    df = df.reset_index()
    df['Tasa Abandono (%)'] = round(df['Churn'] / (df['Churn'] + df['No Churn']) * 100, 2)
    df = df.sort_values(by='Tasa Abandono (%)', ascending=False)
    return df

# %%
def table_rate_churn(df: pd.DataFrame,
                     col: str,
                     pct_col: str='Tasa Abandono (%)',
                     figsize: Tuple=(6,3),
                     title_translate: str=None,
                     save_as: str=None):

    if pct_col != 'Tasa Abandono (%)':
        label = pct_col
    else:
        label = 'Tasa de Abandono (%)'

    data = df[[col, 'Tasa Abandono (%)']].values.tolist()

    if title_translate is None:
        title_translate = col
    if save_as is None:
        save_as = col

    # Crear tabla para exportar como imagen
    fig, ax = plt.subplots(figsize=figsize)
    # Eliminar los ejes
    ax.axis('off')

    color_order= []
    max_rate = max(data, key=lambda x: x[1])
    idx_max = data.index(max_rate)

    for i in range(len(df)):
        if i == idx_max:
            color_order.append('tomato')
        else:
            color_order.append('silver')

    cell_colors = [[color, color] for color in color_order]

    tabla = ax.table(cellText=data,
                     colLabels=[col, label],
                     cellLoc='center',
                     loc='center',
                     colColours=['silver' for i in range(len(data[0]))],
                     cellColours=cell_colors)

    plt.title(f'Evasión (Churn) - {title_translate}', fontsize=18)

    # Escalar la tabla para mayor legibilidad
    tabla.scale(1, 2)

    plt.tight_layout()

    fig.savefig(figures_path/f'rate_Churn_{save_as}.png',
                transparent=False,
                dpi=300,
                bbox_inches='tight')


    plt.show()
    return fig

# %%
churn_ratio_internetservice = pivot_y_tasa_abandono(df_internet_service, 'InternetService')

# %%
rate_internet_service = table_rate_churn(churn_ratio_internetservice,
                                         col='InternetService',
                                         title_translate='Servicio de Internet')

# %% [markdown]
# Observaciones: Deserción (Churn) en función del tipo de servicio
#
# Servicio Telefónico (PhoneService)
#
# El servicio telefónico no muestra una incidencia relevante en la deserción de clientes. Las proporciones de quienes permanecen y quienes se retiran son prácticamente equivalentes:
#
# Clientes que se retiran:
#
# Con servicio telefónico: 90.9%
#
# Sin servicio telefónico: 9.1%
#
# Clientes que permanecen:
#
# Con servicio telefónico: 90.1%
#
# Sin servicio telefónico: 9.9%
#
# Esto indica que el PhoneService no constituye un elemento determinante en la fidelización o pérdida de usuarios.
#
# Servicio de Internet (InternetService)
#
# En este caso, se evidencia un contraste mucho más marcado según el tipo de conexión contratada:
#
# Fibra óptica:
#
# Tasa de deserción: 41.89%
#
# Tasa de permanencia: 58.11%
#
# Servicio DSL:
#
# Tasa de deserción: 18.96%
#
# Tasa de permanencia: 81.04%
#
# Sin servicio de internet:
#
# Tasa de deserción: 7.4%
#
# Tasa de permanencia: 92.6%
#
# Los clientes con fibra óptica presentan la tasa de abandono más elevada, mientras que quienes no poseen servicio de internet son los más propensos a continuar.
#
# Conclusión
#
# El contraste evidente entre los clientes con fibra óptica y aquellos sin servicio de internet constituye un indicador sólido de insatisfacción, especialmente en lo relacionado con el servicio de fibra.
#
# Será necesario profundizar en si este fenómeno se origina por:
#
# Deficiencias de calidad o estabilidad del servicio,
#
# Percepción de una relación costo-beneficio desfavorable,
#
# O factores vinculados a la atención al cliente, procesos de instalación, soporte técnico, entre otros.

# %% [markdown]
# ### 5. ¿Hay asociación entre la cantidad de servicios contratados y la deserción del cliente?

# %%
mapeo_columnas = ['PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies']

for columna in mapeo_columnas:
    df_servicios[columna] = df_servicios[columna].map({'Yes': 1, 'No': 0})

# %%
df_servicios['InternetService'] = df_servicios['InternetService'].map({'DSL': 1, 'Fiber optic': 1, 'No': 0})

# %%
sumando_columnas = ['PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies']

# %%
df_servicios['Cantidad de Servicios'] = df_servicios[sumando_columnas].sum(axis=1)
df_servicios.head()
# Out:
#   Churn  PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0    No             1              0                1               0
# 1    No             1              1                1               0
# 2   Yes             1              0                1               0
# 3   Yes             1              0                1               0
# 4   Yes             1              0                1               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             1                 0            1            1                0
# 1             0                 0            0            0                1
# 2             0                 1            0            0                0
# 3             1                 1            0            1                1
# 4             0                 0            1            1                0
#
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# ...

# %%
df_cantidad_servicios = df_servicios.groupby('Cantidad de Servicios')['Churn'].value_counts().to_frame()
df_cantidad_servicios.reset_index(inplace=True)
df_cantidad_servicios
# Out:
#     Cantidad de Servicios Churn  count
# 0                       1    No   1126
# 1                       1   Yes    138
# 2                       2    No    593
# 3                       2   Yes    266
# 4                       3    No    466
# 5                       3   Yes    380
# 6                       4    No    613
# 7                       4   Yes    352
# 8                       5    No    633
# 9                       5   Yes    289
# 10                      6    No    676
# 11                      6   Yes    232
# 12                      7    No    524
# 13                      7   Yes    152
# 14                      8    No    346
# 15                      8   Yes     49
# 16                      9    No    197
# 17                      9   Yes     11

# %%
cantidad_servicios = []
tasa_abandono = []

for i in range(1, df_cantidad_servicios['Cantidad de Servicios'].max()+1):
    q = df_cantidad_servicios[df_cantidad_servicios['Cantidad de Servicios'] == i]
    churn = q.loc[q['Churn'] == 'Yes', 'count'].item()
    total = q['count'].sum()
    tasa_abandono.append(round(churn / total * 100, 2))
    cantidad_servicios.append(i)

tasa_abandono
# Out:
# [np.float64(10.92),
#  np.float64(30.97),
#  np.float64(44.92),
#  np.float64(36.48),
#  np.float64(31.34),
#  np.float64(25.55),
#  np.float64(22.49),
#  np.float64(12.41),
#  np.float64(5.29)]

# %%
servicios_abandono = pd.DataFrame({'Cantidad Servicios': cantidad_servicios, 'Tasa Abandono (%)': tasa_abandono})
servicios_abandono
# Out:
#    Cantidad Servicios  Tasa Abandono (%)
# 0                   1              10.92
# 1                   2              30.97
# 2                   3              44.92
# 3                   4              36.48
# 4                   5              31.34
# 5                   6              25.55
# 6                   7              22.49
# 7                   8              12.41
# 8                   9               5.29

# %%
servicios_abandono.columns = ['Cantidad de Servicios', 'Tasa Abandono (%)']

# %%
data = servicios_abandono[['Cantidad de Servicios', 'Tasa Abandono (%)']].values.tolist()
for dato in data:
    dato[0] = int(dato[0])

# Crear tabla para exportar como imagen
fig, ax = plt.subplots(figsize=(6, 5))
# Eliminar los ejes
ax.axis('off')

# Usando un mapa de colores para el degradado
cmap = plt.cm.Reds # Usando el mapa de color rojo
min_rate = servicios_abandono['Tasa Abandono (%)'].min()
max_rate = servicios_abandono['Tasa Abandono (%)'].max()

cell_colors = []
for rate in servicios_abandono['Tasa Abandono (%)']:
    # Normalizando el ratio entre 0 y 1
    normalized_rate = (rate - min_rate) / (max_rate - min_rate) if max_rate > min_rate else 0
    color = cmap(normalized_rate)
    cell_colors.append([color, color]) # Aplicando el color


# Tabla
tabla = ax.table(cellText=data,
                 colLabels=['Cantidad de Servicios', 'Tasa de Abandono (%)'],
                 cellLoc='center',
                 loc='center',
                 colColours=['silver', 'silver'],
                 cellColours=cell_colors)

plt.title('Evasión (Churn) - Cantidad de Servicios Contratados', fontsize=18
         )
# Escalar la tabla para mayor legibilidad
tabla.scale(1, 2)
plt.tight_layout()

fig.savefig(figures_path/'rate_Churn_Cantidad_de_servicios.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')


plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax = sns.lineplot(data=servicios_abandono, x='Cantidad de Servicios', y='Tasa Abandono (%)', marker='o')
ax.set_title('Tasa de Abandono según Cantidad de Servicios Contratados', fontsize=18, pad=20)
ax.set_xlabel('Cantidad de Servicios', fontsize=15)
ax.set_ylabel('Tasa de Abandono (%)', fontsize=15)
ax.tick_params(axis='both', labelsize=12)

sns.despine()

plt.grid(True, alpha=0.35)
plt.tight_layout()

fig.savefig(figures_path/'line_rate_Churn_Cant_Serv.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')
plt.show()

# %%
un_servicio = df_servicios[df_servicios['Cantidad de Servicios'] == 1]
servicio_telefono = un_servicio[un_servicio['PhoneService'] == 1].shape[0]
un_servicio = un_servicio.shape[0]
print(f'Cantidad de clientes con un único servicio: {un_servicio}, de los cuales {servicio_telefono} cuentan solo con Servicio Telefónico')
# Out:
# Cantidad de clientes con un único servicio: 1264, de los cuales 1184 cuentan solo con Servicio Telefónico

# %%
print(f'El {round(servicio_telefono / un_servicio * 100, 2)} % de clientes con un sólo servicio corresponde a Servicio Telefónico')
# Out:
# El 93.67 % de clientes con un sólo servicio corresponde a Servicio Telefónico

# %% [markdown]
# Observaciones: Índice de desvinculación según número de servicios adquiridos El estudio revela que los usuarios que contratan una cantidad limitada de servicios tienden a abandonar con mayor frecuencia la compañía.
# El porcentaje de retiro alcanza su nivel más elevado entre quienes poseen tres servicios (~45%) y decrece de forma sostenida conforme se incrementa el número de prestaciones contratadas. Esto indica que los clientes que aprovechan una oferta más amplia y conectada de servicios muestran una mayor lealtad.
#
# Asimismo, el índice de abandono es relativamente bajo entre los usuarios que disponen de un único servicio, dado que el 93.67% de ellos utilizan exclusivamente el Servicio Telefónico. Este dato coincide con el análisis previo, en el cual se concluyó que esta condición no guarda una correlación significativa con la decisión de abandonar la empresa.

# %% [markdown]
# ### 6. ¿Qué tipo de contrato adquirido por el cliente muestra mayor propensión a la cancelación?

# %%
contratos = df_servicios.groupby('Contract')['Churn'].value_counts().to_frame()
contratos.reset_index(inplace=True)
contratos
# Out:
#          Contract Churn  count
# 0  Month-to-month    No   2220
# 1  Month-to-month   Yes   1655
# 2        One year    No   1307
# 3        One year   Yes    166
# 4        Two year    No   1647
# 5        Two year   Yes     48

# %%
df_contratos = pivot_y_tasa_abandono(contratos, 'Contract')
df_contratos
# Out:
#          Contract  No Churn  Churn  Tasa Abandono (%)
# 0  Month-to-month      2220   1655              42.71
# 1        One year      1307    166              11.27
# 2        Two year      1647     48               2.83

# %%
rate_contratos = table_rate_churn(df_contratos,
                                  col='Contract',
                                  title_translate='Tipo de Contrato (Contract)')

# %%
def barh_stack_churn(df: pd.DataFrame,
                     ycol: str,
                     figsize: Tuple=(8,3),
                     title_translate: str=None):

    if title_translate is None:
        title_translate = ycol

    fig, ax = plt.subplots(figsize=figsize)

    ax.set_frame_on(False)

    # Barras horizontales
    ax.barh(df[ycol], df['No Churn'], label='No Churn', color=churn_colors['No'])
    ax.barh(df[ycol], df['Churn'], left=df['No Churn'], label='Churn', color=churn_colors['Yes'])

    for idx, row in df.iterrows():
        tipo = row[ycol]

        # Etiqueta "No Churn"
        nochurn = row['No Churn'] / 2
        ax.text(nochurn, tipo, str(row['No Churn']), va='center', ha='center', color='black', fontsize=9)

        # Etiqueta "Churn"
        churn = row['No Churn'] + row['Churn'] / 2
        ax.text(churn, tipo, str(row['Churn']), va='center', ha='center', color='black', fontsize=9)

    # Etiquetas y título
    ax.set_title(f'Evasión (Churn) de clientes según {title_translate}', fontsize=18, loc='left', pad=20)
    ax.xaxis.set_visible(False)
    ax.tick_params(size=0, labelsize=10)
    ax.legend()
    sns.despine()

    plt.tight_layout()

    fig.savefig(figures_path/f'barhstk_Churn_{ycol}.png',
                transparent=False,
                dpi=300,
                bbox_inches='tight')

    plt.show()
    return fig

# %%
barh_stack_contract = barh_stack_churn(df_contratos,
                                       ycol='Contract',
                                      title_translate='\nTipo de contrato (Contract)')

# %% [markdown]
# Este estudio confirma que la retención de clientes está fuertemente relacionada con el tipo de acuerdo que mantienen con la empresa. Los porcentajes de cancelación registrados son los siguientes:
#
# Contrato mensual: 42.71%
#
# Contrato anual: 11.27%
#
# Contrato bienal: 2.83%
#
# Se observa que los usuarios con contratos de renovación mensual muestran una inclinación más alta a suspender el servicio. En cambio, a medida que el vínculo contractual se extiende en el tiempo, la posibilidad de desvinculación se reduce de manera significativa.

# %% [markdown]
# ### 7. ¿Alguna forma de pago influye en la decisión de abandono del cliente?

# %%
tipo_de_pago = df_servicios.groupby('PaymentMethod')['Churn'].value_counts().to_frame()
tipo_de_pago.reset_index(inplace=True)
tipo_de_pago
# Out:
#                PaymentMethod Churn  count
# 0  Bank transfer (automatic)    No   1286
# 1  Bank transfer (automatic)   Yes    258
# 2    Credit card (automatic)    No   1290
# 3    Credit card (automatic)   Yes    232
# 4           Electronic check    No   1294
# 5           Electronic check   Yes   1071
# 6               Mailed check    No   1304
# 7               Mailed check   Yes    308

# %%
df_tipo_de_pago = pivot_y_tasa_abandono(tipo_de_pago, 'PaymentMethod')
df_tipo_de_pago
# Out:
#                PaymentMethod  No Churn  Churn  Tasa Abandono (%)
# 2           Electronic check      1294   1071              45.29
# 3               Mailed check      1304    308              19.11
# 0  Bank transfer (automatic)      1286    258              16.71
# 1    Credit card (automatic)      1290    232              15.24

# %%
table_rate_paymet_method = table_rate_churn(df_tipo_de_pago,
                                            'PaymentMethod',
                                            figsize=(6,4),
                                            title_translate='Método de pago')

# %%
barh_stack_contract = barh_stack_churn(df_tipo_de_pago,
                                       ycol='PaymentMethod',
                                       title_translate='\nMétodo de pago (PaymentMethod)')

# %% [markdown]
# Observaciones: Índice de cancelación según modalidad de pago Del presente estudio se desprenden los siguientes aspectos relevantes:
#
# Los sistemas de pago automatizado, como la Transferencia Bancaria y la Tarjeta de Crédito, exhiben las tasas de cancelación más reducidas. Esto podría atribuirse a la mayor practicidad, certeza en los plazos de cobro —lo que previene interrupciones del servicio—, o a otros elementos no contemplados en los datos disponibles para este análisis.
#
# El método de pago mediante cheque enviado por correo presenta una tasa de desvinculación moderadamente baja, aunque superior a la de los mecanismos automáticos. Una explicación posible es que, al tratarse de una opción más convencional, sea preferida por usuarios acostumbrados a ella, quienes tienden a mantener una relación más constante con la compañía.
#
# Por otro lado, el pago vía cheque electrónico refleja el mayor índice de abandono. Una hipótesis razonable es que el envío digital de facturas puede ocasionar que el mensaje se extravíe o pase desapercibido, generando retrasos en el pago y posibles cortes del servicio. Sería pertinente analizar si los clientes que se desvinculan bajo esta modalidad pertenecen al grupo de personas mayores. De confirmarse, esto podría evidenciar una brecha tecnológica o dificultades de adaptación, lo que abriría la puerta a implementar medidas de apoyo y asistencia personalizada para mejorar la experiencia de este segmento.
#
# Conclusiones: Servicios Contratados Del estudio sobre la relación entre los servicios adquiridos y la tasa de cancelación, se destacan los siguientes hallazgos:
#
# Los usuarios que cuentan únicamente con el servicio telefónico presentan una baja tasa de desvinculación, lo que sugiere una percepción positiva generalizada respecto a este servicio.
#
# En contraste, quienes utilizan el servicio de Fibra Óptica muestran una tasa de abandono considerablemente más elevada, lo que podría reflejar deficiencias en la calidad o expectativas no satisfechas.
#
# Los contratos de renovación mensual y los clientes con pocos servicios contratados son los que muestran mayor tendencia a cancelar.
#
# Se detecta una insatisfacción significativa entre los usuarios que emplean el método de Factura Electrónica.
#
# Recomendaciones Estratégicas
#
# Profundizar en las causas del abandono del servicio de Fibra Óptica, considerando:
#
# Revisión de opiniones y valoraciones negativas.
#
# Análisis de indicadores técnicos (como velocidad o estabilidad de conexión).
#
# Comparación con otras soluciones tecnológicas ofrecidas por la empresa.
#
# Desarrollar campañas de comunicación segmentadas que promuevan la contratación de servicios adicionales bajo acuerdos de mayor duración (por ejemplo, planes anuales), con el objetivo de:
#
# Disminuir la tasa de cancelación mediante un mayor compromiso.
#
# Incrementar la percepción de valor al combinar múltiples servicios.
#
# Optimizar la experiencia del cliente con el sistema de Factura Electrónica, identificando obstáculos o puntos críticos, especialmente entre adultos mayores o usuarios con menor dominio digital:
#
# Fomentar el uso de métodos de pago automáticos como alternativa confiable y accesible, reduciendo los abandonos vinculados a olvidos o interrupciones por falta de pago.

# %% [markdown]
# ## Perfil del Cliente

# %% [markdown]
#  ### 8. ¿Algún género tiene mayor tendencia a dejar la empresa?

# %%
df_perfil = df_plano.copy()

# %%
df_perfil.head(0)
# Out:
# Empty DataFrame
# Columns: [customerID, Churn, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, Charges.Monthly, Charges.Total, Charges.Daily]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_perfil.groupby('gender')['gender'].value_counts() # La diferencia entre la cantidad de clientes de cada género no es significativa para este análisis.
# Out:
# gender
# Female    3488
# Male      3555
# Name: count, dtype: int64

# %%
df_generos = df_perfil.groupby('gender')['Churn'].value_counts().to_frame()
df_generos.reset_index(inplace=True)
df_generos
# Out:
#    gender Churn  count
# 0  Female    No   2549
# 1  Female   Yes    939
# 2    Male    No   2625
# 3    Male   Yes    930

# %%
bar_gender = bar_churn(df_generos,
                       xcol='gender',
                       title_translate='Género (gender)')

# %% [markdown]
# Observaciones: Cancelación del servicio en función del Género El patrón de desvinculación se presenta de manera prácticamente equilibrada entre hombres y mujeres, lo que sugiere que el atributo Género no ofrece un valor significativo como variable explicativa para anticipar o comprender el comportamiento de abandono. En consecuencia, no representa un elemento clave al momento de definir acciones orientadas a la fidelización de clientes.

# %% [markdown]
#  ### 9. ¿La edad (específicamente ser un ciudadano mayor), influye en la posibilidad de que un cliente abandone?

# %%
df_perfil.groupby('SeniorCitizen')['Churn'].value_counts()
# Out:
# SeniorCitizen  Churn
# No             No       4508
#                Yes      1393
# Yes            No        666
#                Yes       476
# Name: count, dtype: int64

# %%
df_senior = df_perfil.groupby('SeniorCitizen')['Churn'].value_counts().to_frame()
df_senior.reset_index(inplace=True)
df_senior
# Out:
#   SeniorCitizen Churn  count
# 0            No    No   4508
# 1            No   Yes   1393
# 2           Yes    No    666
# 3           Yes   Yes    476

# %%
bar_churn_senior_citizen = bar_churn(df_senior,
                                     xcol='SeniorCitizen',
                                     xlabel='SeniorCitizen',
                                     title_translate='\ncondición de Adulto Mayor (SeniorCitizen)')

# %%
# Pivoteando los datos
df_senior = pivot_y_tasa_abandono(df_senior, 'SeniorCitizen')
df_senior
# Out:
#   SeniorCitizen  No Churn  Churn  Tasa Abandono (%)
# 1           Yes       666    476              41.68
# 0            No      4508   1393              23.61

# %%
table_rate_senior_citizen = table_rate_churn(df_senior,
                                             'SeniorCitizen',
                                             figsize=(5,3),
                                             title_translate='Adulto Mayor (SeniorCitizen)')

# %% [markdown]
# Observaciones: Desvinculación según condición de Adulto Mayor (SeniorCitizen) El estudio evidencia una marcada diferencia en la proporción de cancelaciones entre los usuarios, dependiendo de si pertenecen al segmento de Adultos Mayores.
#
# Las personas de 65 años o más presentan una tasa de desistimiento considerablemente más alta, lo que indica que este grupo etario podría estar enfrentando mayores obstáculos o experimentando un nivel de satisfacción más bajo con los servicios proporcionados por la empresa.
#
#  Análisis detallado: Formas de pago empleadas por Adultos Mayores que discontinuaron el servicio Con el propósito de indagar en las posibles razones detrás de esta mayor tasa de abandono, se examina la distribución de los medios de pago utilizados por los Adultos Mayores que han optado por finalizar su vínculo con la compañía.

# %%
df_senior_churn = df_plano.query('SeniorCitizen == "Yes" & Churn == "Yes"')
df_senior_churn = df_senior_churn.groupby('PaymentMethod')['PaymentMethod'].value_counts().to_frame()
df_senior_churn.reset_index(inplace=True)
df_senior_churn
# Out:
#                PaymentMethod  count
# 0  Bank transfer (automatic)     53
# 1    Credit card (automatic)     62
# 2           Electronic check    317
# 3               Mailed check     44

# %%
total = df_senior_churn['count'].sum()
df_senior_churn['Proporción'] = round(df_senior_churn["count"] / total * 100, 2)
df_senior_churn
# Out:
#                PaymentMethod  count  Proporción
# 0  Bank transfer (automatic)     53       11.13
# 1    Credit card (automatic)     62       13.03
# 2           Electronic check    317       66.60
# 3               Mailed check     44        9.24

# %%
data = df_senior_churn[['PaymentMethod', 'Proporción']].values.tolist()


# Crear tabla para exportar como imagen
fig, ax = plt.subplots(figsize=(6, 3))
# Eliminar los ejes
ax.axis('off')

color_order=['silver', 'silver', 'tomato', 'silver']
cell_colors = [[color, color] for color in color_order]
# Tabla
tabla = ax.table(cellText=data,
                 colLabels=['Payment Method', 'Proporción (%)'],
                 cellLoc='center',
                 loc='center',
                 colColours=['silver', 'silver'],
                 cellColours=cell_colors)

plt.title('Medios de Pago (PaymentMethod) utilizados por\nAdultos Mayores (Senior Citizen) que abandonan', fontsize=18)
# Escalar la tabla para mayor legibilidad
tabla.scale(1, 2)

plt.tight_layout()

fig.savefig(figures_path/'table_SeniorCitizen_PaymentMethod.png',
            transparent=False,
            dpi=300,
            bbox_inches='tight')


plt.show()

# %% [markdown]
# Observaciones: Deserción de Adultos Mayores según modalidad de pago El 66.6% de los clientes de edad avanzada que se desvinculan de la compañía emplean el cheque electrónico como forma de pago. Esta pauta refuerza la suposición expuesta en el apartado de Servicios, sugiriendo que podrían existir barreras relacionadas con el uso de tecnologías o complicaciones en la operativa de este sistema, particularmente entre usuarios de mayor edad.

# %% [markdown]
#  ### 10. ¿Existe relación entre la situación familiar del cliente (pareja, personas a cargo) y la posibilidad de abandono?

# %%
df_pareja = df_perfil.groupby('Churn')['Partner'].value_counts().to_frame()
df_pareja.reset_index(inplace=True)

# %%
bar_pareja = bar_churn(df_pareja,
                       xcol='Partner',
                       xlabel='Partner',
                       title_translate='\ncondición de Pareja (Partner)')

# %%
# Pivoteando los datos
df_pareja = pivot_y_tasa_abandono(df_pareja, 'Partner')
df_pareja
# Out:
#   Partner  No Churn  Churn  Tasa Abandono (%)
# 0      No      2441   1200              32.96
# 1     Yes      2733    669              19.66

# %%
table_rate_partner = table_rate_churn(df_pareja,
                                      'Partner',
                                      title_translate='\nCondición de Pareja (Partner)')

# %% [markdown]
# Observaciones: Abandono según situación conyugal del cliente.
# Los usuarios que no cuentan con una pareja presentan una tasa de cancelación
# 12.3% superior en comparación con quienes sí tienen una relación.
# Esta variación sugiere que el hecho de tener pareja podría estar vinculado a una mayor permanencia o vínculo con el servicio.
#
# Una posible interpretación de esta diferencia es que los clientes en pareja tienden a compartir ciertos servicios, particularmente aquellos que implican el uso de múltiples líneas telefónicas. Esta práctica podría generar ventajas económicas o mayor comodidad, lo que contribuiría a disminuir la probabilidad de que estos usuarios abandonen la compañía.

# %% [markdown]
# Clientes con personas a cargo (Dependendientes)

# %%
df_dependents = df_perfil.groupby('Churn')['Dependents'].value_counts().to_frame()

# %%
df_dependents.reset_index(inplace=True)

# %%
bar_dependents = bar_churn(df_dependents,
                           xcol='Dependents',
                           xlabel='Dependientes',
                           title_translate='\nPersonas a cargo (Dependientes)')

# %%
df_dependents =  pivot_y_tasa_abandono(df_dependents, 'Dependents')
df_dependents
# Out:
#   Dependents  No Churn  Churn  Tasa Abandono (%)
# 0         No      3390   1543              31.28
# 1        Yes      1784    326              15.45

# %%
table_rate_dependents = table_rate_churn(df_dependents,
                                         'Dependents',
                                         title_translate='\nPersonas a cargo (Dependents)')

# %% [markdown]
# Observaciones:
# Abandono según presencia de personas a cargo (Dependientes).
#
# Los usuarios que no cuentan con personas bajo su responsabilidad presentan una tasa de cancelación superior al doble en comparación con aquellos que sí tienen dependientes. Esta diferencia sugiere que la estructura familiar podría estar vinculada a una mayor permanencia o compromiso con los servicios contratados.
#
# Se puede extender esta interpretación al análisis de beneficios derivados de la combinación de servicios, como el uso de múltiples líneas telefónicas, para evaluar si dicha integración influye en la tasa de abandono entre clientes con y sin personas a cargo.

# %% [markdown]
# Análisis: ¿Tener personas a cargo + Múltiples Líneas = menor evasión?

# %%
df_familias = df_perfil.query('Dependents == "Yes"')
df_familias = df_familias.groupby('MultipleLines')['Churn'].value_counts().to_frame()
df_familias.reset_index(inplace=True)
df_familias = pivot_y_tasa_abandono(df_familias, 'MultipleLines')
df_familias
# Out:
#   MultipleLines  No Churn  Churn  Tasa Abandono (%)
# 1           Yes       717    134              15.75
# 0            No      1067    192              15.25

# %%
table_rate_dependents = table_rate_churn(df_familias,
                                         'MultipleLines',
                                         title_translate='\nPersonas a cargo con Multiples Líneas',
                                         save_as='Dependents_MultipleLines')

# %% [markdown]
# Observaciones: Personas a cargo + Múltiples Líneas
#
# "MultipleLines" no aporta poder explicativo al análisis de Evasión "Churn" ya que la tasa de abandono entre ambos grupos es prácticamente simétrica.

# %% [markdown]
# Conclusiones: Características del cliente
#
# Respecto a la deserción de usuarios según su perfil demográfico, se pueden resaltar los siguientes puntos:
#
# Sexo (Gender): La variable relacionada con el sexo no evidencia variaciones relevantes en la proporción de cancelaciones. La distribución entre hombres y mujeres es prácticamente equilibrada, lo que indica que esta característica no tiene poder explicativo en relación con la pérdida de clientes.
#
# Personas mayores (SeniorCitizen): Los usuarios de 65 años o más presentan una tasa de desvinculación considerablemente más alta que el resto de los segmentos. Este grupo mantiene una fuerte asociación con el uso del sistema de pago mediante cheque electrónico, empleado por el 66.6% de los adultos mayores que se retiran del servicio. Esto podría reflejar dificultades en el uso de plataformas digitales o barreras de accesibilidad que impactan negativamente en su experiencia.
#
# Situación conyugal (Tener Pareja) y responsabilidad familiar (Dependientes): Los clientes que no tienen pareja ni personas bajo su cuidado tienden a mostrar una mayor inclinación a finalizar su contrato. Esta tendencia permite diseñar estrategias de fidelización enfocadas en usuarios individuales, quienes podrían responder positivamente a propuestas personalizadas o soluciones adaptadas a sus circunstancias particulares.

# %% [markdown]
# # 4 Puntos Clave: Interpretación y Representación de Datos

# %% [markdown]
# Se detectaron tendencias evidentes de cancelación vinculadas con la duración como cliente (Tenure) y el importe total acumulado (ChargesTotal), siendo estos factores determinantes para anticipar la deserción.
#
# La mayoría de los usuarios que se retiran lo hacen en fases iniciales, aunque también se identificó un segmento de clientes de alto valor económico que opta por dejar el servicio, lo que requiere un estudio más detallado.
#
# Un alto desembolso mensual (ChargesMonthly > 79 USD) se asocia con una mayor tasa de abandono, lo que sugiere una posible sensibilidad al costo en grupos de consumo medio-alto.
#
# La modalidad de servicio contratada tiene un impacto directo en la retención: quienes cuentan con conexión por Fibra Óptica (Fiber Optic) presentan mayores niveles de cancelación, mientras que los que disponen únicamente de línea telefónica (PhoneService) muestran mayor permanencia.
#
# Los acuerdos mensuales renovables (Month-to-Month) y la adquisición limitada de servicios se relacionan con una mayor tendencia a la baja continuidad.
#
# El sistema de pago mediante transferencia electrónica (Electronic Check) exhibe una alta correlación con la cancelación, especialmente entre usuarios de edad avanzada, lo que apunta a dificultades tecnológicas o deficiencias en la experiencia de uso.
#
# El sexo del cliente no representa una variable significativa en la deserción, evidenciando una distribución equitativa entre géneros.
#
# Los adultos mayores (SeniorCitizen) presentan una frecuencia de abandono superior, sobre todo cuando se combina con el uso de Electronic Check.
#
# Los usuarios sin pareja ni dependientes muestran una mayor inclinación a suspender sus servicios, lo que subraya la importancia de diseñar estrategias específicas para perfiles individuales.
#
# Estos descubrimientos permiten identificar grupos vulnerables y guiar medidas proactivas, como optimización de la experiencia digital, incentivos por paquetes integrados y ajustes tarifarios personalizados.

# %% [markdown]
# # 5 Analísis de Correlación

# %%
col_norm = ['SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

# %%
df_corr = df_plano.copy()

# %%
df_corr['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
for col in col_norm:
    df_corr[col] = df_corr[col].map({'Yes': 1, 'No': 0})

# %%
df_corr['InternetService'] = pd.Categorical(df_corr['InternetService'], categories=['No', 'DSL', 'Fiber optic'])
dummies_internet = pd.get_dummies(df_corr['InternetService'], drop_first=True).astype(int)
dummies_genero = pd.get_dummies(df_corr['gender']).astype(int)
dummies_payment = pd.get_dummies(df_corr['PaymentMethod']).astype(int)
dummies_contratos = pd.get_dummies(df_corr['Contract']).astype(int)

# %%
df_corr = pd.concat([df_corr, dummies_internet, dummies_genero, dummies_payment, dummies_contratos], axis=1)

# %%
df_corr.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines InternetService  ...  Fiber optic  Female  \
# 0             1              0             DSL  ...            0       1
# 1             1              1             DSL  ...            0       0
# 2             1              0     Fiber optic  ...            1       0
# 3             1              0     Fiber optic  ...            1       0
# 4             1              0     Fiber optic  ...            1       1
#
#    Male  Bank transfer (automatic)  Credit card (automatic)  Electronic check  \
# ...

# %%
df_corr.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly', 'Charges.Total',
#        'Charges.Daily', 'DSL', 'Fiber optic', 'Female', 'Male',
#        'Bank transfer (automatic)', 'Credit card (automatic)',
#        'Electronic check', 'Mailed check', 'Month-to-month', 'One year',
#        'Two year'],
#       dtype='object')

# %%
cols_corr = ['Female', 'Male', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'DSL', 'Fiber optic',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Month-to-month', 'One year',
       'Two year', 'PaperlessBilling',
       'Bank transfer (automatic)', 'Credit card (automatic)',
       'Electronic check', 'Mailed check' , 'Charges.Daily', 'Charges.Monthly', 'Charges.Total',
       'Churn'
       ]

df_corr = df_corr[cols_corr]
df_corr
# Out:
#       Female  Male  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          1     0              0        1           1       9             1
# 1          0     1              0        0           0       9             1
# 2          0     1              0        0           0       4             1
# 3          0     1              1        1           0      13             1
# 4          1     0              1        1           0       3             1
# ...      ...   ...            ...      ...         ...     ...           ...
# 7262       1     0              0        0           0      13             1
# 7263       0     1              0        1           0      22             1
# 7264       0     1              0        0           0       2             1
# 7265       0     1              0        1           1      67             1
# 7266       0     1              0        1           1      63             0
#
# ...

# %%
corr = df_corr.corr()

# %%
# Eliminamos variables con coef.coerr de Churn que sean < a 0.07:
cols_drop = ['Female', 'Male', 'PhoneService', 'MultipleLines', 'StreamingTV', 'StreamingMovies']
df_corr = df_corr.drop(cols_drop, axis=1)
df_corr.head()
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  DSL  Fiber optic  \
# 0              0        1           1       9    1            0
# 1              0        0           0       9    1            0
# 2              0        0           0       4    0            1
# 3              1        1           0      13    0            1
# 4              1        1           0       3    0            1
#
#    OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  ...  Two year  \
# 0               0             1                 0            1  ...         0
# 1               0             0                 0            0  ...         0
# 2               0             0                 1            0  ...         0
# 3               0             1                 1            0  ...         0
# 4               0             0                 0            1  ...         0
#
#    PaperlessBilling  Bank transfer (automatic)  Credit card (automatic)  \
# ...

# %%
corr = df_corr.corr()

fig, ax = plt.subplots(figsize=(16,10))

ax = sns.heatmap(corr, cbar=True, square=False, annot=True, fmt='.2f',
                annot_kws={'size':10}, cmap='mako_r')

ax.set_title('Heatmap de Correlación entre Variables', fontsize=18, pad=20, loc='left')
ax.tick_params(axis='both',labelsize=12)
plt.show()

# %%
corr['Churn'].to_frame().sort_values('Churn')
# Out:
#                               Churn
# tenure                    -0.352229
# Two year                  -0.302253
# Charges.Total             -0.198324
# One year                  -0.177820
# OnlineSecurity            -0.171226
# TechSupport               -0.164674
# Dependents                -0.164221
# Partner                   -0.150448
# Credit card (automatic)   -0.134302
# DSL                       -0.124214
# Bank transfer (automatic) -0.117937
# Mailed check              -0.091683
# OnlineBackup              -0.082255
# DeviceProtection          -0.066160
# SeniorCitizen              0.150889
# PaperlessBilling           0.191825
# Charges.Monthly            0.193356
# Charges.Daily              0.193412
# Electronic check           0.301919
# Fiber optic                0.308020
# Month-to-month             0.405103
# Churn                      1.000000

# %% [markdown]
# Análisis Preliminar de Correlaciones: Variables vs Churn
# 🎯 Objetivo del análisis
# Explorar la relación entre las variables del dataset y la variable objetivo Churn (abandono del cliente), utilizando variables transformadas en formato binario (dummies). Aunque Churn es una variable categórica binaria (0: retención, 1: salida), este análisis permite identificar asociaciones iniciales relevantes.
#
# 📌 Metodología
# Se utilizó el coeficiente de correlación de Pearson, que mide relaciones lineales entre variables.
#
# Este análisis no determina causalidad, pero orienta la exploración de patrones útiles para el modelo final.
#
# El modelo definitivo será una regresión logística, que evalúa la relación entre las variables independientes y el logaritmo de las probabilidades de que Churn = 1.
#
# 🔍 Principales Hallazgos
#
# Variable	Tipo de Correlación	Coeficiente	Interpretación
# Tenure (Antigüedad)	Negativa	-0.35	A mayor antigüedad, menor probabilidad de abandono.
#
# ChargesTotal	Negativa	-0.20	Clientes con cargos acumulados altos tienden a permanecer.
#
# ChargesDaily / Monthly	Positiva	0.19	Ambas correlacionan igual; se evaluará cuál incluir según VIF.
#
# Month-to-month (Contrato)	Positiva	0.41	Contrato flexible, facilita cancelación.
#
# Two year (Contrato largo)	Negativa	-0.30	Compromisos largos se asocian a mayor retención.
#
# OnlineSecurity / TechSupport	Negativa	~ -0.25	Servicios adicionales favorecen la permanencia.
#
# Electronic check (Pago)	Positiva	0.30	Mayor churn asociado a este método de pago.
#
# Bank transfer / Credit card	Negativa	~ -0.20	Métodos automáticos se vinculan a menor churn.
#
# 📘 Conclusión
#
# Este análisis de correlación proporciona una base sólida para entender qué variables podrían influir en la evasión de clientes. Aunque no define el impacto definitivo en el modelo de clasificación, sí permite priorizar variables para pruebas más profundas y ajustar la estrategia de retención.

# %%
df.to_csv("datos_tratados.csv", index=False)

# %% [markdown]
# 7. Carga de Datos Pre-Procesados

# %%
df_preprocess = df_plano.copy()

# %%
df_preprocess.head()
# Out:
#    customerID Churn  gender SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female            No     Yes        Yes       9
# 1  0003-MKNFE    No    Male            No      No         No       9
# 2  0004-TLHLJ   Yes    Male            No      No         No       4
# 3  0011-IGKFF   Yes    Male           Yes     Yes         No      13
# 4  0013-EXCHZ   Yes  Female           Yes     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0          Yes            No             DSL  ...               No
# 1          Yes           Yes             DSL  ...               No
# 2          Yes            No     Fiber optic  ...              Yes
# 3          Yes            No     Fiber optic  ...              Yes
# 4          Yes            No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
data_path = Path('src')

if not data_path.exists():
    data_path.mkdir(parents=True)  # 'parents=True' crea directorios intermedios si es necesario
    print("Directorio creado.")
else:
    print("El directorio ya existe.")
# Out:
# Directorio creado.

# %%
df_preprocess.to_json(data_path/'preprocessed_TelecomX_data.json')

# %%
df_preprocess.to_csv("datos_tratados.csv", index=False)
